# %%
import cv2
import matplotlib.pyplot as plt
import skt_face

# %%
imgpath = './26_1.jpg'
img = cv2.imread(imgpath)
phone_num = 5122
school_name = 'snu'

info = skt_face.call(phone_num, school_name, imgpath)

print('name: ', info['name'])
print('face location: ', info['faceLoc'])
print('conf: ', info['conf'])
# Out:
# AICLOUD RDV SERVER
#  78EE7769B2A0463CBE16A5DB9FD9F704
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8782cc2c3f0f> in <module>()
#       4 school_name = 'snu'
#       5
# ----> 6 info = skt_face.call(phone_num, school_name, imgpath)
#       7
#       8 print('name: ', info['name'])
#
# /home/ubuntu/code/skt_face.py in call(phone_num, school_name, inputimg)
#      55     tttt = ''
#      56     while True:
# ---> 57         data = clientsock.recv(BUFSIZE)
#      58
#      59         if data == '\x00\x00\x00\n\x00\x00\x00\x040000':
#
# KeyboardInterrupt:

# %%
txt = 'rid: %s, conf: %s' % ('kimchulsu', info['conf']) #opencv에서는 한글 입력이 안 됩니다. 영문으로 바꿔주세요.
print txt
# Out:
# rid: kimchulsu, conf: 0.995581

# %%
x = info['faceLoc']['pointX']
y = info['faceLoc']['pointY']
w = info['faceLoc']['width']
h = info['faceLoc']['height']
cv2.putText(img, txt, (x + 10, y + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2)

# %%
cv2.rectangle(img, (x, y), (x + w, y + h), (255,255,255), 5)
J = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(J)
plt.show()
